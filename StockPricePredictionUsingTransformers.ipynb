# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add, GlobalAveragePooling1D

import yfinance as yf

# %%
def calculate_bollinger_bands(data, window=10, num_of_std=2):
    """Calculate Bollinger Bands"""
    rolling_mean = data.rolling(window=window).mean()
    rolling_std = data.rolling(window=window).std()
    upper_band = rolling_mean + (rolling_std * num_of_std)
    lower_band = rolling_mean - (rolling_std * num_of_std)
    return upper_band, lower_band

def calculate_rsi(data, window=10):
    """Calculate Relative Strength Index"""
    delta = data.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_roc(data, periods=10):
    """Calculate Rate of Change."""
    roc = ((data - data.shift(periods)) / data.shift(periods)) * 100
    return roc

# %%
tickers = ['META', 'AAPL', 'MSFT', 'AMZN', 'GOOG']
tickers = ['META', 'AAPL', 'MSFT', 'AMZN', 'GOOG', 'NVDA', 'TSLA', 'AVGO', 'ADBE', 'CRM', 'AMD', 'QCOM', 'ASML']
tickers = ['META', 'AAPL', 'MSFT', 'AMZN', 'GOOG', 'NVDA', 'TSLA', 'AVGO', 'ADBE', 'CRM','AMD', 'QCOM', 'ASML', 'ORCL', 'NOW', 'INTU', 'SNPS', 'CDNS', 'TXN', 'MU', 'LRCX', 'AMAT', 'KLAC', 'PANW', 'TMUS', 'VZ', 'T', 'SNOW', 'CRWD', 'DDOG', 'NET', 'SHOP', 'MELI']

# %%
ticker_data_frames = []
stats = {}
for ticker in tickers:

    # Download historical data for the ticker
    data = yf.download(ticker, period="60d", interval="5m")

    # Calculate the daily percentage change
    close = data['Close'][ticker]
    upper, lower = calculate_bollinger_bands(close, window=14, num_of_std=2)
    width = upper - lower
    rsi = calculate_rsi(close, window=14)
    roc = calculate_roc(close, periods=14)
    volume = data['Volume'][ticker]
    diff = data['Close'][ticker].diff(1)
    percent_change_close = data['Close'][ticker].pct_change() * 100

    # Create a DataFrame for the current ticker and append it to the list
    ticker_df = pd.DataFrame({
        ticker+'_close': close,
        ticker+'_width': width,
        ticker+'_rsi': rsi,
        ticker+'_roc': roc,
        ticker+'_volume': volume,
        ticker+'_diff': diff,
        ticker+'_percent_change_close': percent_change_close,
    })

    MEAN = ticker_df.mean()
    STD = ticker_df.std()

    # Keep track of mean and std
    for column in MEAN.index:
      stats[f"{column}_mean"] = MEAN[column]
      stats[f"{column}_std"] = STD[column]

    # Normalize the training features
    ticker_df = (ticker_df - MEAN) / STD

    ticker_data_frames.append(ticker_df)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Convert stats from dict to df
stats = pd.DataFrame([stats], index=[0])
stats.head()
# Out:
#    META_close_mean  META_close_std  META_width_mean  META_width_std  \
# 0       641.152464       46.741145         7.045409        5.986911
#
#    META_rsi_mean  META_rsi_std  META_roc_mean  META_roc_std  META_volume_mean  \
# 0      51.172855     17.232379       0.047764      0.856933     150656.468316
#
#    META_volume_std  ...  MELI_rsi_mean  MELI_rsi_std  MELI_roc_mean  \
# 0    187136.848589  ...       49.85442     15.929748       0.011559
#
#    MELI_roc_std  MELI_volume_mean  MELI_volume_std  MELI_diff_mean  \
# 0      1.052911       4791.496517      6141.617469        0.014058
#
#    MELI_diff_std  MELI_percent_change_close_mean  \
# 0       6.290158                        0.001148
#
#    MELI_percent_change_close_std
# 0                       0.316239
#
# [1 rows x 462 columns]

# %%
# Concatenate all ticker DataFrames
df = pd.concat(ticker_data_frames, axis=1)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#                            META_close  META_width  META_rsi  META_roc  \
# Datetime
# 2024-11-26 15:40:00+00:00   -1.418160    0.039225  1.420924  1.131320
# 2024-11-26 15:45:00+00:00   -1.420107    0.111058  1.366074  1.081027
# 2024-11-26 15:50:00+00:00   -1.420254    0.115975  1.392559  1.095142
# 2024-11-26 15:55:00+00:00   -1.406528    0.188260  1.323010  0.987755
# 2024-11-26 16:00:00+00:00   -1.364161    0.413934  1.468095  1.217139
#
#                            META_volume  META_diff  META_percent_change_close  \
# Datetime
# 2024-11-26 15:40:00+00:00     0.109222   0.376505                   0.418787
# 2024-11-26 15:45:00+00:00     1.032146  -0.077289                  -0.086125
# 2024-11-26 15:50:00+00:00    -0.009963  -0.018258                  -0.020500
# 2024-11-26 15:55:00+00:00     0.192894   0.436477                   0.485125
# 2024-11-26 16:00:00+00:00     1.097050   1.375398                   1.527400
#
#                            AAPL_close  AAPL_width  AAPL_rsi  ...  SHOP_volume  \
# Datetime                                                     ...
# 2024-11-26 15:40:00+00:00   -0.559784    0.010970  0.681216  ...    -0.281619
# 2024-11-26 15:45:00+00:00   -0.573970    0.111977  0.414910  ...    -0.200161
# 2024-11-26 15:50:00+00:00   -0.572878    0.196221  0.522140  ...    -0.224040
# 2024-11-26 15:55:00+00:00   -0.589256    0.182887 -0.138572  ...    -0.034024
# 2024-11-26 16:00:00+00:00   -0.568514    0.246843  0.269996  ...    -0.215751
#
#                            SHOP_diff  SHOP_percent_change_close  MELI_close  \
# Datetime
# 2024-11-26 15:40:00+00:00   0.376386                   0.384403    1.584918
# 2024-11-26 15:45:00+00:00   0.831455                   0.850096    1.494776
# 2024-11-26 15:50:00+00:00  -0.024839                  -0.027065    1.522852
# 2024-11-26 15:55:00+00:00  -0.899604                  -0.920730    1.538814
# 2024-11-26 16:00:00+00:00   0.870479                   0.890353    1.510239
#
#                            MELI_width  MELI_rsi  MELI_roc  MELI_volume  \
# Datetime
# 2024-11-26 15:40:00+00:00    0.481013  0.376079  0.720095    -0.040787
# 2024-11-26 15:45:00+00:00    0.473116  0.016547  0.004758    -0.282905
# 2024-11-26 15:50:00+00:00    0.578506 -0.241686 -0.499630    -0.300327
# 2024-11-26 15:55:00+00:00    0.627574 -0.334579 -0.660939    -0.415444
# 2024-11-26 16:00:00+00:00    0.615486 -0.626912 -1.176539    -0.326054
#
#                            MELI_diff  MELI_percent_change_close
# Datetime
# 2024-11-26 15:40:00+00:00  -0.753424                  -0.704873
# 2024-11-26 15:45:00+00:00  -2.013298                  -1.885150
# 2024-11-26 15:50:00+00:00   0.624131                   0.585896
# 2024-11-26 15:55:00+00:00   0.353875                   0.330911
# 2024-11-26 16:00:00+00:00  -0.639740                  -0.601892
#
# [5 rows x 231 columns]

# %%
# Shift the df data to create labels
labels = df.shift(-1)

# Drop the last row in both percent_change_data and labels as it won't have a corresponding label
df = df.iloc[:-1]
labels = labels.iloc[:-1]

# %%
# Sequence len = 24 means that we have 2 hours of 5 min data
SEQUENCE_LEN = 24

# Function to create X-day sequences for each ticker
def create_sequences(data, labels, mean, std, sequence_length=SEQUENCE_LEN):
    sequences = []
    lab = []
    data_size = len(data)

    # + 12 because we want to predict the next hour
    #for i in range(data_size - (sequence_length + 13)):
    for i in range(data_size - (sequence_length + 2)):
      if i == 0:
        continue

      sequences.append(data[i:i + sequence_length])
      #lab.append([labels[i-1], labels[i + 12], mean[0], std[0]])
      lab.append([labels[i-1], labels[i + 1], mean[0], std[0]])

    for i in range(0, len(lab)):
      last_price_data = sequences[i][-1][0]
      last_price_label = lab[i][0]

      if not last_price_data == last_price_label:
        print(f"ERROR : {last_price_data=} and {last_price_label=} are not equal")

    return np.array(sequences), np.array(lab)

# %%
sequences_dict = {}
sequence_labels = {}
for ticker in tickers:

    # Extract close and volume data for the ticker
    close = df[ticker+'_close'].values
    width = df[ticker+'_width'].values
    rsi = df[ticker+'_rsi'].values
    roc = df[ticker+'_roc'].values
    volume = df[ticker+'_volume'].values
    diff = df[ticker+'_diff'].values
    pct_change = df[ticker+'_percent_change_close'].values

    # Combine close and volume data
    ticker_data = np.column_stack((close,
                                   width,
                                   rsi,
                                   roc,
                                   volume,
                                   diff,
                                   pct_change))

    # Generate sequences
    attribute = ticker+"_close"
    ticker_sequences, lab = create_sequences(ticker_data,
                                             labels[attribute].values[SEQUENCE_LEN-1:],
                                             stats[attribute+"_mean"].values,
                                             stats[attribute+"_std"].values)

    sequences_dict[ticker] = ticker_sequences
    sequence_labels[ticker] = lab

# %%
# Combine data and labels from all tickers
all_sequences = []
all_labels = []

for ticker in tickers:
    all_sequences.extend(sequences_dict[ticker])
    all_labels.extend(sequence_labels[ticker])

# Convert to numpy arrays
all_sequences = np.array(all_sequences)
all_labels = np.array(all_labels)

# %%
np.random.seed(42)
shuffled_indices = np.random.permutation(len(all_sequences))
all_sequences = all_sequences[shuffled_indices]
all_labels = all_labels[shuffled_indices]

train_size = int(len(all_sequences) * 0.9)

# Split sequences
train_sequences = all_sequences[:train_size]
train_labels    = all_labels[:train_size]

other_sequences = all_sequences[train_size:]
other_labels    = all_labels[train_size:]

shuffled_indices = np.random.permutation(len(other_sequences))
other_sequences = other_sequences[shuffled_indices]
other_labels = other_labels[shuffled_indices]

val_size = int(len(other_sequences) * 0.5)

validation_sequences = other_sequences[:val_size]
validation_labels = other_labels[:val_size]

test_sequences = other_sequences[val_size:]
test_labels = other_labels[val_size:]

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    # Feed Forward Part
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation="relu")(y)
    y = Dropout(dropout)(y)
    y = Dense(inputs.shape[-1])(y)
    return Add()([y, x])

def build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout=0):
    inputs = Input(shape=input_shape)
    x = inputs

    # Create multiple layers of the Transformer block
    for _ in range(num_layers):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # Final part of the model
    x = GlobalAveragePooling1D()(x)
    x = LayerNormalization(epsilon=1e-6)(x)
    outputs = Dense(1, activation="linear")(x)

    # Compile model
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Model parameters
input_shape = train_sequences.shape[1:]
head_size = 256
num_heads = 16
ff_dim = 1024
num_layers = 12
dropout = 0.20

# Build the model
model = build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 24, 7)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 24, 7)          │             14 │ input_layer[0][0]      │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 24, 7)          │        126,983 │ layer_normalization[0… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 24, 7)          │              0 │ multi_head_attention[… │
# │                           │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 24, 7)          │             14 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 24, 1024)       │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 24, 7)          │              0 │ dense_1[0][0],         │
# │                           │                        │                │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_2     │ (None, 24, 7)          │             14 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_1    │ (None, 24, 7)          │        126,983 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_3     │ (None, 24, 7)          │             14 │ add_2[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 24, 7)          │              0 │ dense_3[0][0],         │
# │                           │                        │                │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_4     │ (None, 24, 7)          │             14 │ add_3[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_2    │ (None, 24, 7)          │        126,983 │ layer_normalization_4… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_5     │ (None, 24, 7)          │             14 │ add_4[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 24, 7)          │              0 │ dense_5[0][0],         │
# │                           │                        │                │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_6     │ (None, 24, 7)          │             14 │ add_5[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_3    │ (None, 24, 7)          │        126,983 │ layer_normalization_6… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_7     │ (None, 24, 7)          │             14 │ add_6[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 24, 7)          │              0 │ dense_7[0][0],         │
# │                           │                        │                │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_8     │ (None, 24, 7)          │             14 │ add_7[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_4    │ (None, 24, 7)          │        126,983 │ layer_normalization_8… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 24, 7)          │             14 │ add_8[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 24, 7)          │              0 │ dense_9[0][0],         │
# │                           │                        │                │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 24, 7)          │             14 │ add_9[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_5    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 24, 7)          │             14 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 24, 7)          │              0 │ dense_11[0][0],        │
# │                           │                        │                │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 24, 7)          │             14 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 24, 7)          │             14 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 24, 7)          │              0 │ dense_13[0][0],        │
# │                           │                        │                │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 24, 7)          │             14 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_13[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 24, 7)          │             14 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 24, 7)          │              0 │ dense_15[0][0],        │
# │                           │                        │                │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_16    │ (None, 24, 7)          │             14 │ add_15[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_8    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_15[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_17    │ (None, 24, 7)          │             14 │ add_16[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 24, 7)          │              0 │ dense_17[0][0],        │
# │                           │                        │                │ add_16[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_18    │ (None, 24, 7)          │             14 │ add_17[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_9    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_17[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_19    │ (None, 24, 7)          │             14 │ add_18[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_19 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_19[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 24, 7)          │              0 │ dense_19[0][0],        │
# │                           │                        │                │ add_18[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_20    │ (None, 24, 7)          │             14 │ add_19[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_10   │ (None, 24, 7)          │        126,983 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_19[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_21    │ (None, 24, 7)          │             14 │ add_20[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_21 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_21[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_21 (Add)              │ (None, 24, 7)          │              0 │ dense_21[0][0],        │
# │                           │                        │                │ add_20[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_22    │ (None, 24, 7)          │             14 │ add_21[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_11   │ (None, 24, 7)          │        126,983 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_22 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_21[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_23    │ (None, 24, 7)          │             14 │ add_22[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_23 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_23[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_23 (Add)              │ (None, 24, 7)          │              0 │ dense_23[0][0],        │
# │                           │                        │                │ add_22[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 7)              │              0 │ add_23[0][0]           │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_24    │ (None, 7)              │             14 │ global_average_poolin… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 1)              │              8 │ layer_normalization_2… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,708,558 (6.52 MB)
#  Trainable params: 1,708,558 (6.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def custom_mae_loss(y_true, y_pred):
    y_true_next = tf.cast(y_true[:, 1], tf.float64)
    y_pred_next = tf.cast(y_pred[:, 0], tf.float64)
    abs_error = tf.abs(y_true_next - y_pred_next)

    return tf.reduce_mean(abs_error)

def dir_acc(y_true, y_pred):
    mean, std = tf.cast(y_true[:, 2], tf.float64), tf.cast(y_true[:, 3], tf.float64)

    y_true_prev = (tf.cast(y_true[:, 0], tf.float64) * std) + mean
    y_true_next = (tf.cast(y_true[:, 1], tf.float64) * std) + mean
    y_pred_next = (tf.cast(y_pred[:, 0], tf.float64) * std) + mean

    true_change = y_true_next - y_true_prev
    pred_change = y_pred_next - y_true_prev

    correct_direction = tf.equal(tf.sign(true_change), tf.sign(pred_change))

    return tf.reduce_mean(tf.cast(correct_direction, tf.float64))

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss=custom_mae_loss, metrics=[dir_acc])

# %%
# Define a callback to save the best model
checkpoint_callback_train = ModelCheckpoint(
    "transformer_train_model.keras",  # Filepath to save the best model
    monitor="dir_acc",  #"loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

# Define a callback to save the best model
checkpoint_callback_val = ModelCheckpoint(
    "transformer_val_model.keras",  # Filepath to save the best model
    monitor="val_dir_acc", #"val_loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

def get_lr_callback(batch_size=16, mode='cos', epochs=500, plot=False):
    lr_start, lr_max, lr_min = 0.0001, 0.005, 0.00001  # Adjust learning rate boundaries
    lr_ramp_ep = int(0.30 * epochs)  # 30% of epochs for warm-up
    lr_sus_ep = max(0, int(0.10 * epochs) - lr_ramp_ep)  # Optional sustain phase, adjust as needed

    def lrfn(epoch):
        if epoch < lr_ramp_ep:  # Warm-up phase
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        elif epoch < lr_ramp_ep + lr_sus_ep:  # Sustain phase at max learning rate
            lr = lr_max
        elif mode == 'cos':
            decay_total_epochs, decay_epoch_index = epochs - lr_ramp_ep - lr_sus_ep, epoch - lr_ramp_ep - lr_sus_ep
            phase = math.pi * decay_epoch_index / decay_total_epochs
            lr = (lr_max - lr_min) * 0.5 * (1 + math.cos(phase)) + lr_min
        else:
            lr = lr_min  # Default to minimum learning rate if mode is not recognized

        return lr

    if plot:  # Plot learning rate curve if plot is True
        plt.figure(figsize=(10, 5))
        plt.plot(np.arange(epochs), [lrfn(epoch) for epoch in np.arange(epochs)], marker='o')
        plt.xlabel('Epoch')
        plt.ylabel('Learning Rate')
        plt.title('Learning Rate Scheduler')
        plt.show()

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %%
BATCH_SIZE = 64
EPOCHS = 100
model.fit(train_sequences, train_labels,
          validation_data=(validation_sequences, validation_labels),
          epochs=EPOCHS,
          batch_size=BATCH_SIZE,
          shuffle=True,
          callbacks=[checkpoint_callback_train, checkpoint_callback_val, get_lr_callback(batch_size=BATCH_SIZE, epochs=EPOCHS)])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dir_acc: 0.4980 - loss: 0.1845
# Epoch 1: dir_acc improved from -inf to 0.49940, saving model to transformer_train_model.keras
#
# Epoch 1: val_dir_acc improved from -inf to 0.49957, saving model to transformer_val_model.keras
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 149s 47ms/step - dir_acc: 0.4980 - loss: 0.1845 - val_dir_acc: 0.4996 - val_loss: 0.1567 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00026333333333333336.
# Epoch 2/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5003 - loss: 0.1430
# Epoch 2: dir_acc improved from 0.49940 to 0.50125, saving model to transformer_train_model.keras
#
# Epoch 2: val_dir_acc improved from 0.49957 to 0.51307, saving model to transformer_val_model.keras
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5003 - loss: 0.1430 - val_dir_acc: 0.5131 - val_loss: 0.1213 - learning_rate: 2.6333e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00042666666666666667.
# Epoch 3/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5034 - loss: 0.1277
# Epoch 3: dir_acc improved from 0.50125 to 0.50227, saving model to transformer_train_model.keras
#
# Epoch 3: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - dir_acc: 0.5034 - loss: 0.1277 - val_dir_acc: 0.5114 - val_loss: 0.1469 - learning_rate: 4.2667e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00059.
# Epoch 4/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5046 - loss: 0.1236
# Epoch 4: dir_acc improved from 0.50227 to 0.50261, saving model to transformer_train_model.keras
#
# Epoch 4: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5046 - loss: 0.1236 - val_dir_acc: 0.5045 - val_loss: 0.1127 - learning_rate: 5.9000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0007533333333333334.
# Epoch 5/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5032 - loss: 0.1148
# Epoch 5: dir_acc improved from 0.50261 to 0.50372, saving model to transformer_train_model.keras
#
# Epoch 5: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5032 - loss: 0.1148 - val_dir_acc: 0.5021 - val_loss: 0.1186 - learning_rate: 7.5333e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0009166666666666668.
# Epoch 6/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5022 - loss: 0.1118
# Epoch 6: dir_acc did not improve from 0.50372
#
# Epoch 6: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5022 - loss: 0.1118 - val_dir_acc: 0.5043 - val_loss: 0.1206 - learning_rate: 9.1667e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00108.
# Epoch 7/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5027 - loss: 0.1091
# Epoch 7: dir_acc did not improve from 0.50372
#
# Epoch 7: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5027 - loss: 0.1091 - val_dir_acc: 0.5025 - val_loss: 0.1098 - learning_rate: 0.0011
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0012433333333333335.
# Epoch 8/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5054 - loss: 0.1070
# Epoch 8: dir_acc did not improve from 0.50372
#
# Epoch 8: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5054 - loss: 0.1070 - val_dir_acc: 0.5126 - val_loss: 0.1049 - learning_rate: 0.0012
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0014066666666666667.
# Epoch 9/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5063 - loss: 0.1018
# Epoch 9: dir_acc improved from 0.50372 to 0.50591, saving model to transformer_train_model.keras
#
# Epoch 9: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5063 - loss: 0.1018 - val_dir_acc: 0.5077 - val_loss: 0.0985 - learning_rate: 0.0014
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00157.
# Epoch 10/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5048 - loss: 0.1025
# Epoch 10: dir_acc did not improve from 0.50591
#
# Epoch 10: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5048 - loss: 0.1025 - val_dir_acc: 0.5020 - val_loss: 0.0973 - learning_rate: 0.0016
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0017333333333333335.
# Epoch 11/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5053 - loss: 0.0977
# Epoch 11: dir_acc did not improve from 0.50591
#
# Epoch 11: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5053 - loss: 0.0977 - val_dir_acc: 0.5078 - val_loss: 0.0982 - learning_rate: 0.0017
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0018966666666666667.
# Epoch 12/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5045 - loss: 0.0986
# Epoch 12: dir_acc did not improve from 0.50591
#
# Epoch 12: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5045 - loss: 0.0986 - val_dir_acc: 0.5054 - val_loss: 0.0910 - learning_rate: 0.0019
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0020599999999999998.
# Epoch 13/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5067 - loss: 0.0967
# Epoch 13: dir_acc did not improve from 0.50591
#
# Epoch 13: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5067 - loss: 0.0967 - val_dir_acc: 0.5002 - val_loss: 0.0881 - learning_rate: 0.0021
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0022233333333333332.
# Epoch 14/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5056 - loss: 0.0941
# Epoch 14: dir_acc did not improve from 0.50591
#
# Epoch 14: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5056 - loss: 0.0941 - val_dir_acc: 0.5121 - val_loss: 0.0906 - learning_rate: 0.0022
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0023866666666666667.
# Epoch 15/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5018 - loss: 0.0948
# Epoch 15: dir_acc did not improve from 0.50591
#
# Epoch 15: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5018 - loss: 0.0948 - val_dir_acc: 0.5113 - val_loss: 0.1015 - learning_rate: 0.0024
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0025499999999999997.
# Epoch 16/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5051 - loss: 0.0946
# Epoch 16: dir_acc did not improve from 0.50591
#
# Epoch 16: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5051 - loss: 0.0946 - val_dir_acc: 0.5019 - val_loss: 0.1245 - learning_rate: 0.0026
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0027133333333333332.
# Epoch 17/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5046 - loss: 0.0942
# Epoch 17: dir_acc did not improve from 0.50591
#
# Epoch 17: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5046 - loss: 0.0942 - val_dir_acc: 0.4994 - val_loss: 0.1379 - learning_rate: 0.0027
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0028766666666666667.
# Epoch 18/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5071 - loss: 0.0940
# Epoch 18: dir_acc improved from 0.50591 to 0.50683, saving model to transformer_train_model.keras
#
# Epoch 18: val_dir_acc did not improve from 0.51307
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5071 - loss: 0.0940 - val_dir_acc: 0.5066 - val_loss: 0.0907 - learning_rate: 0.0029
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0030399999999999997.
# Epoch 19/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5100 - loss: 0.0935
# Epoch 19: dir_acc improved from 0.50683 to 0.50990, saving model to transformer_train_model.keras
#
# Epoch 19: val_dir_acc improved from 0.51307 to 0.51591, saving model to transformer_val_model.keras
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5100 - loss: 0.0935 - val_dir_acc: 0.5159 - val_loss: 0.0882 - learning_rate: 0.0030
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.003203333333333333.
# Epoch 20/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5085 - loss: 0.0928
# Epoch 20: dir_acc did not improve from 0.50990
#
# Epoch 20: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5085 - loss: 0.0928 - val_dir_acc: 0.5121 - val_loss: 0.1017 - learning_rate: 0.0032
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0033666666666666667.
# Epoch 21/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5070 - loss: 0.0931
# Epoch 21: dir_acc did not improve from 0.50990
#
# Epoch 21: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5070 - loss: 0.0931 - val_dir_acc: 0.5046 - val_loss: 0.0866 - learning_rate: 0.0034
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0035299999999999997.
# Epoch 22/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5057 - loss: 0.0931
# Epoch 22: dir_acc did not improve from 0.50990
#
# Epoch 22: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5057 - loss: 0.0931 - val_dir_acc: 0.5104 - val_loss: 0.0853 - learning_rate: 0.0035
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.003693333333333333.
# Epoch 23/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5095 - loss: 0.0916
# Epoch 23: dir_acc did not improve from 0.50990
#
# Epoch 23: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5095 - loss: 0.0916 - val_dir_acc: 0.5044 - val_loss: 0.0956 - learning_rate: 0.0037
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0038566666666666667.
# Epoch 24/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5075 - loss: 0.0916
# Epoch 24: dir_acc did not improve from 0.50990
#
# Epoch 24: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5075 - loss: 0.0916 - val_dir_acc: 0.5035 - val_loss: 0.0925 - learning_rate: 0.0039
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00402.
# Epoch 25/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5059 - loss: 0.0921
# Epoch 25: dir_acc did not improve from 0.50990
#
# Epoch 25: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5059 - loss: 0.0921 - val_dir_acc: 0.5077 - val_loss: 0.0918 - learning_rate: 0.0040
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.004183333333333334.
# Epoch 26/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5051 - loss: 0.0904
# Epoch 26: dir_acc did not improve from 0.50990
#
# Epoch 26: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5051 - loss: 0.0904 - val_dir_acc: 0.5035 - val_loss: 0.1115 - learning_rate: 0.0042
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.004346666666666667.
# Epoch 27/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5047 - loss: 0.0922
# Epoch 27: dir_acc did not improve from 0.50990
#
# Epoch 27: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5047 - loss: 0.0922 - val_dir_acc: 0.5127 - val_loss: 0.1255 - learning_rate: 0.0043
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00451.
# Epoch 28/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5055 - loss: 0.0927
# Epoch 28: dir_acc did not improve from 0.50990
#
# Epoch 28: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5055 - loss: 0.0927 - val_dir_acc: 0.5026 - val_loss: 0.0851 - learning_rate: 0.0045
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004673333333333334.
# Epoch 29/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5060 - loss: 0.0933
# Epoch 29: dir_acc did not improve from 0.50990
#
# Epoch 29: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5060 - loss: 0.0933 - val_dir_acc: 0.5059 - val_loss: 0.1217 - learning_rate: 0.0047
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.004836666666666667.
# Epoch 30/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5063 - loss: 0.0942
# Epoch 30: dir_acc did not improve from 0.50990
#
# Epoch 30: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5063 - loss: 0.0942 - val_dir_acc: 0.5058 - val_loss: 0.1023 - learning_rate: 0.0048
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.005.
# Epoch 31/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5051 - loss: 0.0929
# Epoch 31: dir_acc did not improve from 0.50990
#
# Epoch 31: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5051 - loss: 0.0929 - val_dir_acc: 0.5050 - val_loss: 0.0869 - learning_rate: 0.0050
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00499748770102058.
# Epoch 32/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5053 - loss: 0.0920
# Epoch 32: dir_acc did not improve from 0.50990
#
# Epoch 32: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5053 - loss: 0.0920 - val_dir_acc: 0.5080 - val_loss: 0.0939 - learning_rate: 0.0050
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0049899558635181215.
# Epoch 33/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5049 - loss: 0.0923
# Epoch 33: dir_acc did not improve from 0.50990
#
# Epoch 33: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5049 - loss: 0.0923 - val_dir_acc: 0.5139 - val_loss: 0.0876 - learning_rate: 0.0050
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.004977419655610997.
# Epoch 34/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5095 - loss: 0.0915
# Epoch 34: dir_acc did not improve from 0.50990
#
# Epoch 34: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5095 - loss: 0.0915 - val_dir_acc: 0.5031 - val_loss: 0.0887 - learning_rate: 0.0050
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.004959904323553581.
# Epoch 35/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5083 - loss: 0.0899
# Epoch 35: dir_acc did not improve from 0.50990
#
# Epoch 35: val_dir_acc did not improve from 0.51591
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5083 - loss: 0.0899 - val_dir_acc: 0.5104 - val_loss: 0.0979 - learning_rate: 0.0050
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0049374451408936496.
# Epoch 36/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5053 - loss: 0.0910
# Epoch 36: dir_acc did not improve from 0.50990
#
# Epoch 36: val_dir_acc improved from 0.51591 to 0.52133, saving model to transformer_val_model.keras
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5053 - loss: 0.0910 - val_dir_acc: 0.5213 - val_loss: 0.0894 - learning_rate: 0.0049
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.004910087337436154.
# Epoch 37/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5065 - loss: 0.0910
# Epoch 37: dir_acc did not improve from 0.50990
#
# Epoch 37: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - dir_acc: 0.5065 - loss: 0.0910 - val_dir_acc: 0.5008 - val_loss: 0.0829 - learning_rate: 0.0049
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.004877886008156408.
# Epoch 38/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5050 - loss: 0.0907
# Epoch 38: dir_acc did not improve from 0.50990
#
# Epoch 38: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5050 - loss: 0.0907 - val_dir_acc: 0.5087 - val_loss: 0.0859 - learning_rate: 0.0049
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.004840906002246144.
# Epoch 39/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5077 - loss: 0.0890
# Epoch 39: dir_acc did not improve from 0.50990
#
# Epoch 39: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - dir_acc: 0.5077 - loss: 0.0890 - val_dir_acc: 0.5005 - val_loss: 0.0868 - learning_rate: 0.0048
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00479922179251587.
# Epoch 40/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5084 - loss: 0.0892
# Epoch 40: dir_acc did not improve from 0.50990
#
# Epoch 40: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5084 - loss: 0.0892 - val_dir_acc: 0.5038 - val_loss: 0.0874 - learning_rate: 0.0048
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0047529173254165355.
# Epoch 41/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5094 - loss: 0.0868
# Epoch 41: dir_acc did not improve from 0.50990
#
# Epoch 41: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5094 - loss: 0.0868 - val_dir_acc: 0.5127 - val_loss: 0.1071 - learning_rate: 0.0048
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.004702085851982562.
# Epoch 42/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5064 - loss: 0.0880
# Epoch 42: dir_acc did not improve from 0.50990
#
# Epoch 42: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5064 - loss: 0.0880 - val_dir_acc: 0.5086 - val_loss: 0.0763 - learning_rate: 0.0047
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.004646829740036656.
# Epoch 43/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5102 - loss: 0.0866
# Epoch 43: dir_acc did not improve from 0.50990
#
# Epoch 43: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5102 - loss: 0.0866 - val_dir_acc: 0.5007 - val_loss: 0.1191 - learning_rate: 0.0046
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00458726026803465.
# Epoch 44/100
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5101 - loss: 0.0883
# Epoch 44: dir_acc did not improve from 0.50990
#
# Epoch 44: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5101 - loss: 0.0883 - val_dir_acc: 0.5117 - val_loss: 0.0821 - learning_rate: 0.0046
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.004523497400965494.
# Epoch 45/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5064 - loss: 0.0842
# Epoch 45: dir_acc did not improve from 0.50990
#
# Epoch 45: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5064 - loss: 0.0842 - val_dir_acc: 0.5047 - val_loss: 0.1004 - learning_rate: 0.0045
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.004455669548757734.
# Epoch 46/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5056 - loss: 0.0874
# Epoch 46: dir_acc did not improve from 0.50990
#
# Epoch 46: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5056 - loss: 0.0874 - val_dir_acc: 0.4982 - val_loss: 0.0918 - learning_rate: 0.0045
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00438391330767901.
# Epoch 47/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5101 - loss: 0.0863
# Epoch 47: dir_acc did not improve from 0.50990
#
# Epoch 47: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5101 - loss: 0.0863 - val_dir_acc: 0.5072 - val_loss: 0.0801 - learning_rate: 0.0044
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.004308373185249342.
# Epoch 48/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5113 - loss: 0.0851
# Epoch 48: dir_acc did not improve from 0.50990
#
# Epoch 48: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5113 - loss: 0.0851 - val_dir_acc: 0.5075 - val_loss: 0.0798 - learning_rate: 0.0043
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.004229201309222228.
# Epoch 49/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5059 - loss: 0.0847
# Epoch 49: dir_acc did not improve from 0.50990
#
# Epoch 49: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5059 - loss: 0.0847 - val_dir_acc: 0.5076 - val_loss: 0.0893 - learning_rate: 0.0042
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0041465571212195825.
# Epoch 50/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5095 - loss: 0.0842
# Epoch 50: dir_acc did not improve from 0.50990
#
# Epoch 50: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5095 - loss: 0.0842 - val_dir_acc: 0.5028 - val_loss: 0.0799 - learning_rate: 0.0041
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0040606070556375405.
# Epoch 51/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5086 - loss: 0.0839
# Epoch 51: dir_acc did not improve from 0.50990
#
# Epoch 51: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5086 - loss: 0.0839 - val_dir_acc: 0.5091 - val_loss: 0.0783 - learning_rate: 0.0041
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00397152420446972.
# Epoch 52/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5081 - loss: 0.0831
# Epoch 52: dir_acc did not improve from 0.50990
#
# Epoch 52: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5081 - loss: 0.0831 - val_dir_acc: 0.5160 - val_loss: 0.0737 - learning_rate: 0.0040
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0038794879687229964.
# Epoch 53/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5083 - loss: 0.0810
# Epoch 53: dir_acc did not improve from 0.50990
#
# Epoch 53: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5083 - loss: 0.0810 - val_dir_acc: 0.5100 - val_loss: 0.1011 - learning_rate: 0.0039
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0037846836971277367.
# Epoch 54/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5098 - loss: 0.0822
# Epoch 54: dir_acc did not improve from 0.50990
#
# Epoch 54: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5098 - loss: 0.0822 - val_dir_acc: 0.5016 - val_loss: 0.0868 - learning_rate: 0.0038
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.003687302312870132.
# Epoch 55/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5106 - loss: 0.0819
# Epoch 55: dir_acc did not improve from 0.50990
#
# Epoch 55: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5106 - loss: 0.0819 - val_dir_acc: 0.5092 - val_loss: 0.0798 - learning_rate: 0.0037
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0035875399290983077.
# Epoch 56/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5112 - loss: 0.0805
# Epoch 56: dir_acc improved from 0.50990 to 0.51122, saving model to transformer_train_model.keras
#
# Epoch 56: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5112 - loss: 0.0805 - val_dir_acc: 0.5113 - val_loss: 0.0756 - learning_rate: 0.0036
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00348559745397654.
# Epoch 57/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5103 - loss: 0.0796
# Epoch 57: dir_acc did not improve from 0.51122
#
# Epoch 57: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5103 - loss: 0.0796 - val_dir_acc: 0.5080 - val_loss: 0.0779 - learning_rate: 0.0035
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0033816801860829505.
# Epoch 58/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5088 - loss: 0.0803
# Epoch 58: dir_acc did not improve from 0.51122
#
# Epoch 58: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5088 - loss: 0.0803 - val_dir_acc: 0.5055 - val_loss: 0.0815 - learning_rate: 0.0034
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0032759974009654944.
# Epoch 59/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5112 - loss: 0.0797
# Epoch 59: dir_acc did not improve from 0.51122
#
# Epoch 59: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5112 - loss: 0.0797 - val_dir_acc: 0.5116 - val_loss: 0.0747 - learning_rate: 0.0033
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0031687619296888545.
# Epoch 60/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5090 - loss: 0.0783
# Epoch 60: dir_acc did not improve from 0.51122
#
# Epoch 60: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5090 - loss: 0.0783 - val_dir_acc: 0.5099 - val_loss: 0.0758 - learning_rate: 0.0032
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.003060189730221005.
# Epoch 61/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5128 - loss: 0.0784
# Epoch 61: dir_acc did not improve from 0.51122
#
# Epoch 61: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5128 - loss: 0.0784 - val_dir_acc: 0.5103 - val_loss: 0.0851 - learning_rate: 0.0031
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.002950499452522599.
# Epoch 62/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5130 - loss: 0.0773
# Epoch 62: dir_acc improved from 0.51122 to 0.51216, saving model to transformer_train_model.keras
#
# Epoch 62: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5130 - loss: 0.0773 - val_dir_acc: 0.5072 - val_loss: 0.0744 - learning_rate: 0.0030
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0028399119982150506.
# Epoch 63/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5111 - loss: 0.0766
# Epoch 63: dir_acc did not improve from 0.51216
#
# Epoch 63: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5111 - loss: 0.0766 - val_dir_acc: 0.5171 - val_loss: 0.0734 - learning_rate: 0.0028
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.002728650075714067.
# Epoch 64/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5123 - loss: 0.0765
# Epoch 64: dir_acc improved from 0.51216 to 0.51255, saving model to transformer_train_model.keras
#
# Epoch 64: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5123 - loss: 0.0765 - val_dir_acc: 0.5083 - val_loss: 0.0734 - learning_rate: 0.0027
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0026169377517245352.
# Epoch 65/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5119 - loss: 0.0753
# Epoch 65: dir_acc did not improve from 0.51255
#
# Epoch 65: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5119 - loss: 0.0753 - val_dir_acc: 0.5036 - val_loss: 0.0748 - learning_rate: 0.0026
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0025050000000000003.
# Epoch 66/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5122 - loss: 0.0764
# Epoch 66: dir_acc did not improve from 0.51255
#
# Epoch 66: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5122 - loss: 0.0764 - val_dir_acc: 0.5164 - val_loss: 0.0764 - learning_rate: 0.0025
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0023930622482754658.
# Epoch 67/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5125 - loss: 0.0749
# Epoch 67: dir_acc did not improve from 0.51255
#
# Epoch 67: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5125 - loss: 0.0749 - val_dir_acc: 0.5114 - val_loss: 0.0738 - learning_rate: 0.0024
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.002281349924285934.
# Epoch 68/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5135 - loss: 0.0747
# Epoch 68: dir_acc did not improve from 0.51255
#
# Epoch 68: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5135 - loss: 0.0747 - val_dir_acc: 0.5127 - val_loss: 0.0704 - learning_rate: 0.0023
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00217008800178495.
# Epoch 69/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5164 - loss: 0.0731
# Epoch 69: dir_acc improved from 0.51255 to 0.51399, saving model to transformer_train_model.keras
#
# Epoch 69: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5164 - loss: 0.0731 - val_dir_acc: 0.5040 - val_loss: 0.0717 - learning_rate: 0.0022
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.002059500547477402.
# Epoch 70/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5155 - loss: 0.0727
# Epoch 70: dir_acc did not improve from 0.51399
#
# Epoch 70: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5155 - loss: 0.0727 - val_dir_acc: 0.5126 - val_loss: 0.0746 - learning_rate: 0.0021
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.001949810269778996.
# Epoch 71/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5152 - loss: 0.0726
# Epoch 71: dir_acc improved from 0.51399 to 0.51418, saving model to transformer_train_model.keras
#
# Epoch 71: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5152 - loss: 0.0726 - val_dir_acc: 0.5116 - val_loss: 0.0694 - learning_rate: 0.0019
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0018412380703111465.
# Epoch 72/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5143 - loss: 0.0724
# Epoch 72: dir_acc did not improve from 0.51418
#
# Epoch 72: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5143 - loss: 0.0724 - val_dir_acc: 0.5094 - val_loss: 0.0680 - learning_rate: 0.0018
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0017340025990345066.
# Epoch 73/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5151 - loss: 0.0715
# Epoch 73: dir_acc improved from 0.51418 to 0.51464, saving model to transformer_train_model.keras
#
# Epoch 73: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5151 - loss: 0.0715 - val_dir_acc: 0.5170 - val_loss: 0.0746 - learning_rate: 0.0017
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0016283198139170505.
# Epoch 74/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5156 - loss: 0.0714
# Epoch 74: dir_acc did not improve from 0.51464
#
# Epoch 74: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5156 - loss: 0.0714 - val_dir_acc: 0.5155 - val_loss: 0.0677 - learning_rate: 0.0016
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0015244025460234615.
# Epoch 75/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5144 - loss: 0.0704
# Epoch 75: dir_acc did not improve from 0.51464
#
# Epoch 75: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5144 - loss: 0.0704 - val_dir_acc: 0.5193 - val_loss: 0.0696 - learning_rate: 0.0015
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.001422460070901693.
# Epoch 76/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5153 - loss: 0.0703
# Epoch 76: dir_acc did not improve from 0.51464
#
# Epoch 76: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 54s 28ms/step - dir_acc: 0.5153 - loss: 0.0703 - val_dir_acc: 0.5121 - val_loss: 0.0672 - learning_rate: 0.0014
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0013226976871298685.
# Epoch 77/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5180 - loss: 0.0700
# Epoch 77: dir_acc improved from 0.51464 to 0.51518, saving model to transformer_train_model.keras
#
# Epoch 77: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5180 - loss: 0.0700 - val_dir_acc: 0.5126 - val_loss: 0.0739 - learning_rate: 0.0013
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0012253163028722645.
# Epoch 78/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.5174 - loss: 0.0697
# Epoch 78: dir_acc improved from 0.51518 to 0.51597, saving model to transformer_train_model.keras
#
# Epoch 78: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5174 - loss: 0.0697 - val_dir_acc: 0.5156 - val_loss: 0.0662 - learning_rate: 0.0012
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0011305120312770046.
# Epoch 79/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5178 - loss: 0.0687
# Epoch 79: dir_acc improved from 0.51597 to 0.51650, saving model to transformer_train_model.keras
#
# Epoch 79: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5178 - loss: 0.0687 - val_dir_acc: 0.5137 - val_loss: 0.0682 - learning_rate: 0.0011
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.00103847579553028.
# Epoch 80/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5200 - loss: 0.0684
# Epoch 80: dir_acc improved from 0.51650 to 0.51809, saving model to transformer_train_model.keras
#
# Epoch 80: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5200 - loss: 0.0684 - val_dir_acc: 0.5113 - val_loss: 0.0678 - learning_rate: 0.0010
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00094939294436246.
# Epoch 81/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5176 - loss: 0.0683
# Epoch 81: dir_acc did not improve from 0.51809
#
# Epoch 81: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5176 - loss: 0.0683 - val_dir_acc: 0.5147 - val_loss: 0.0676 - learning_rate: 9.4939e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0008634428787804172.
# Epoch 82/100
# 1894/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5185 - loss: 0.0678
# Epoch 82: dir_acc did not improve from 0.51809
#
# Epoch 82: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5185 - loss: 0.0678 - val_dir_acc: 0.5131 - val_loss: 0.0684 - learning_rate: 8.6344e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0007807986907777728.
# Epoch 83/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5191 - loss: 0.0675
# Epoch 83: dir_acc did not improve from 0.51809
#
# Epoch 83: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - dir_acc: 0.5191 - loss: 0.0675 - val_dir_acc: 0.5139 - val_loss: 0.0679 - learning_rate: 7.8080e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0007016268147506584.
# Epoch 84/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5176 - loss: 0.0673
# Epoch 84: dir_acc did not improve from 0.51809
#
# Epoch 84: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5176 - loss: 0.0673 - val_dir_acc: 0.5140 - val_loss: 0.0648 - learning_rate: 7.0163e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.000626086692320991.
# Epoch 85/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dir_acc: 0.5186 - loss: 0.0664
# Epoch 85: dir_acc did not improve from 0.51809
#
# Epoch 85: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - dir_acc: 0.5186 - loss: 0.0664 - val_dir_acc: 0.5149 - val_loss: 0.0670 - learning_rate: 6.2609e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0005543304512422657.
# Epoch 86/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5189 - loss: 0.0663
# Epoch 86: dir_acc did not improve from 0.51809
#
# Epoch 86: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - dir_acc: 0.5189 - loss: 0.0663 - val_dir_acc: 0.5121 - val_loss: 0.0656 - learning_rate: 5.5433e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00048650259903450645.
# Epoch 87/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5211 - loss: 0.0661
# Epoch 87: dir_acc improved from 0.51809 to 0.51960, saving model to transformer_train_model.keras
#
# Epoch 87: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - dir_acc: 0.5211 - loss: 0.0661 - val_dir_acc: 0.5167 - val_loss: 0.0639 - learning_rate: 4.8650e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00042273973196535.
# Epoch 88/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5235 - loss: 0.0657
# Epoch 88: dir_acc improved from 0.51960 to 0.52044, saving model to transformer_train_model.keras
#
# Epoch 88: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5235 - loss: 0.0657 - val_dir_acc: 0.5187 - val_loss: 0.0667 - learning_rate: 4.2274e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00036317025996334415.
# Epoch 89/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.5213 - loss: 0.0654
# Epoch 89: dir_acc did not improve from 0.52044
#
# Epoch 89: val_dir_acc did not improve from 0.52133
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5213 - loss: 0.0654 - val_dir_acc: 0.5196 - val_loss: 0.0652 - learning_rate: 3.6317e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00030791414801743875.
# Epoch 90/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5226 - loss: 0.0656
# Epoch 90: dir_acc improved from 0.52044 to 0.52096, saving model to transformer_train_model.keras
#
# Epoch 90: val_dir_acc improved from 0.52133 to 0.52150, saving model to transformer_val_model.keras
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - dir_acc: 0.5226 - loss: 0.0656 - val_dir_acc: 0.5215 - val_loss: 0.0642 - learning_rate: 3.0791e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00025708267458346456.
# Epoch 91/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5176 - loss: 0.0652
# Epoch 91: dir_acc did not improve from 0.52096
#
# Epoch 91: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5176 - loss: 0.0652 - val_dir_acc: 0.5203 - val_loss: 0.0643 - learning_rate: 2.5708e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00021077820748413085.
# Epoch 92/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5222 - loss: 0.0649
# Epoch 92: dir_acc improved from 0.52096 to 0.52104, saving model to transformer_train_model.keras
#
# Epoch 92: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5222 - loss: 0.0649 - val_dir_acc: 0.5143 - val_loss: 0.0641 - learning_rate: 2.1078e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00016909399775385568.
# Epoch 93/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5199 - loss: 0.0647
# Epoch 93: dir_acc did not improve from 0.52104
#
# Epoch 93: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5199 - loss: 0.0647 - val_dir_acc: 0.5214 - val_loss: 0.0637 - learning_rate: 1.6909e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.00013211399184359196.
# Epoch 94/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5237 - loss: 0.0647
# Epoch 94: dir_acc improved from 0.52104 to 0.52127, saving model to transformer_train_model.keras
#
# Epoch 94: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5237 - loss: 0.0647 - val_dir_acc: 0.5181 - val_loss: 0.0631 - learning_rate: 1.3211e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 9.991266256384617e-05.
# Epoch 95/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5218 - loss: 0.0643
# Epoch 95: dir_acc did not improve from 0.52127
#
# Epoch 95: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5218 - loss: 0.0643 - val_dir_acc: 0.5134 - val_loss: 0.0635 - learning_rate: 9.9913e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 7.255485910635008e-05.
# Epoch 96/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5203 - loss: 0.0644
# Epoch 96: dir_acc did not improve from 0.52127
#
# Epoch 96: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5203 - loss: 0.0644 - val_dir_acc: 0.5191 - val_loss: 0.0631 - learning_rate: 7.2555e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 5.009567644641898e-05.
# Epoch 97/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5210 - loss: 0.0643
# Epoch 97: dir_acc did not improve from 0.52127
#
# Epoch 97: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - dir_acc: 0.5210 - loss: 0.0643 - val_dir_acc: 0.5185 - val_loss: 0.0630 - learning_rate: 5.0096e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.258034438900293e-05.
# Epoch 98/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5208 - loss: 0.0637
# Epoch 98: dir_acc improved from 0.52127 to 0.52129, saving model to transformer_train_model.keras
#
# Epoch 98: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5208 - loss: 0.0637 - val_dir_acc: 0.5165 - val_loss: 0.0629 - learning_rate: 3.2580e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.0044136481878526e-05.
# Epoch 99/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5178 - loss: 0.0642
# Epoch 99: dir_acc did not improve from 0.52129
#
# Epoch 99: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - dir_acc: 0.5178 - loss: 0.0642 - val_dir_acc: 0.5215 - val_loss: 0.0632 - learning_rate: 2.0044e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.25122989794201e-05.
# Epoch 100/100
# 1895/1896 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dir_acc: 0.5213 - loss: 0.0638
# Epoch 100: dir_acc did not improve from 0.52129
#
# Epoch 100: val_dir_acc did not improve from 0.52150
# 1896/1896 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - dir_acc: 0.5213 - loss: 0.0638 - val_dir_acc: 0.5190 - val_loss: 0.0629 - learning_rate: 1.2512e-05

# %%
# Load Weights
model.load_weights("transformer_val_model.keras")

# Make predictions
accuracy = model.evaluate(test_sequences, test_labels)[1]
print(accuracy)

# Calculate additional metrics as needed
from sklearn.metrics import r2_score

predictions = model.predict(test_sequences)
r2 = r2_score(test_labels[:, 1], predictions[:, 0])
print(f"R-squared: {r2}")
# Out:
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - dir_acc: 0.4989 - loss: 0.0679
# 0.5037727355957031
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step
# R-squared: 0.9900854559285849
